# %% [markdown]
# # Interview data exploration

# %%
import pandas as pd
df = pd.read_csv('./data/participants.csv')

df = df.rename(columns={
    "On a scale from 1 to 10, how do you estimate your programming experience?": "Programming experience (of 10)",
    "How experienced are you with the following language: Python?": "Python experience (of 5)",
    "How experienced are you with the following language: Jayvee?": "Jayvee experience (of 5)",
    "student_id_anon": "ID",
})

df = df[[
    'ID',
    'Programming experience (of 10)',
    'Python experience (of 5)',
    'Jayvee experience (of 5)',
]]

df
# Out:
#     ID  Programming experience (of 10)  Python experience (of 5)  \
# 0    7                               7                         3
# 1    6                               9                         4
# 2    2                               7                         4
# 3    8                               8                         3
# 4   12                               9                         5
# 5   11                               7                         2
# 6    1                               8                         5
# 7    4                               5                         2
# 8    9                               9                         4
# 9    5                               9                         5
# 10   3                               6                         3
# 11  10                               9                         4
# 12   0                               8                         4
#
#     Jayvee experience (of 5)
# ...
